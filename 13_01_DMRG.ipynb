# %%
def psi_dot_psi(psi1, psi2):
    x = 0.
    for i in range(psi1.shape[0]):
        for j in range(psi2.shape[1]):
            x += psi1[i,j]*psi2[i,j]
    return x
            
def lanczos(m, seed, maxiter, tol, use_seed = False, force_maxiter = False):
    x1 = seed
    x2 = seed
    gs = seed
    a = np.zeros(100)
    b = np.zeros(100)
    z = np.zeros((100,100))
    lvectors = []
    control_max = maxiter;
    e0 = 9999

    if(maxiter == -1):
        force_maxiter = False

    if(control_max == 0):
        gs = 1
        maxiter = 1
        return(e0,gs)
    
    x1[:,:] = 0
    x2[:,:] = 0
    gs[:,:] = 0
    a[:] = 0.0
    b[:] = 0.0
    if(use_seed):
        x1 = seed
    else:
        for i in range(x1.shape[0]):
            for j in range(x1.shape[1]):
                x1[i,j] = (2*np.random.random()-1.)

#    x1[:,:] = 1
    b[0] = psi_dot_psi(x1,x1)
    b[0] = np.sqrt(b[0])
    x1 = x1 / b[0]
    x2[:] = 0
    b[0] = 1.

    e0 = 9999
    nmax = min(99, maxiter)

    for iter in range(1,nmax+1):
        eini = e0
        if(b[iter - 1] != 0.):
            aux = x1
            x1 = -b[iter-1] * x2
            x2 = aux / b[iter-1]

        aux = m.product(x2)

        x1 = x1 + aux
        a[iter] = psi_dot_psi(x1,x2)
        x1 = x1 - x2*a[iter]

        b[iter] = psi_dot_psi(x1,x1)
        b[iter] = np.sqrt(b[iter])
        lvectors.append(x2)                                                  
#        print "Iter =",iter,a[iter],b[iter]
        z.resize((iter,iter))
        z[:,:] = 0
        for i in range(0,iter-1):
            z[i,i+1] = b[i+1]
            z[i+1,i] = b[i+1]
            z[i,i] = a[i+1]
        z[iter-1,iter-1]=a[iter]
        d, v = np.linalg.eig(z)

        col = 0
        n = 0
        e0 = 9999
        for e in d:
            if(e < e0):
                e0 = e
                col = n
            n+=1
        e0 = d[col]
        
       
        print "Iter = ",iter," Ener = ",e0
        if((force_maxiter and iter >= control_max) or (iter >= gs.shape[0]*gs.shape[1] or iter == 99 or abs(b[iter]) < tol) or \
            ((not force_maxiter) and abs(eini-e0) <= tol)):
            # converged
            gs[:,:] = 0.
            for n in range(0,iter):
                gs += v[n,col]*lvectors[n]

            print "E0 = ", e0
            maxiter = iter
            return(e0,gs) # We return with ground states energy

    return(e0,gs)

# %%
import numpy as np

class Position:
    LEFT, RIGHT = range(2)

class DMRGSystem(object): 

    def __init__(self, _nsites):

        #Single site operators
        self.nsites = _nsites
        self.nstates = 2
        self.dim_l = 0      # dimension of the left block
        self.dim_r = 0      # dimension of the right block
        self.left_size = 0  # number of sites in the left block
        self.right_size = 0 # number of sites in the right block

        self.sz0 = np.zeros(shape=(2,2)) # single site Sz
        self.splus0 = np.zeros(shape=(2,2)) # single site S+
        self.sz0[0,0]         = -0.5
        self.sz0[1,1]         =  0.5
        self.splus0[1,0]      =  1.0

        #Useful structures to store the matrices

        self.HL = []     # left block Hamiltonian
        self.HR = []     # right block Hamiltonian
        self.szL = []    # left block Sz
        self.szR = []    # right block Sz
        self.splusL = [] # left block S+
        self.splusR = [] # right block S+

        zero_matrix = np.zeros(shape=(2,2))
        for i in range(nsites):
            self.HL.append(zero_matrix)
            self.HR.append(zero_matrix)
            self.szL.append(self.sz0)
            self.szR.append(self.sz0)
            self.splusL.append(self.splus0)
            self.splusR.append(self.splus0)

        self.psi = np.zeros(shape=(2,2)) # g.s. wave function
        self.rho = np.zeros(shape=(2,2)) # density matrix

        self.energy = 0.
        self.error = 0.

#######################################


    def BuildBlockLeft(self, iter):
        self.left_size = iter
        self.dim_l = self.HL[self.left_size-1].shape[0]
        I_left = np.eye(self.dim_l)
        I2 = np.eye(2)
        # enlarge left block:
        self.HL[self.left_size] = np.kron(self.HL[self.left_size-1],I2) + \
                         np.kron(self.szL[self.left_size-1],self.sz0) + \
                         0.5*np.kron(self.splusL[self.left_size-1],self.splus0.transpose()) + \
                         0.5*np.kron(self.splusL[self.left_size-1].transpose(),self.splus0)
        self.splusL[self.left_size] = np.kron(I_left,self.splus0)
        self.szL[self.left_size] = np.kron(I_left,self.sz0)


    def BuildBlockRight(self, iter):
        self.right_size = iter
        self.dim_r = self.HR[self.right_size-1].shape[0]
        I_right= np.eye(self.dim_r)
        I2 = np.eye(2)
        # enlarge right block:
        self.HR[self.right_size] = np.kron(I2,self.HR[self.right_size-1]) + \
                         np.kron(self.sz0,self.szR[self.right_size-1]) + \
                         0.5* np.kron(self.splus0.transpose(),self.splusR[self.right_size-1]) + \
                         0.5* np.kron(self.splus0,self.splusR[self.right_size-1].transpose())
        self.splusR[self.right_size] = np.kron(self.splus0,I_right)
        self.szR[self.right_size] = np.kron(self.sz0,I_right)

    
    def GroundState(self):
        self.dim_l = self.HL[self.left_size].shape[0]
        self.dim_r = self.HR[self.right_size].shape[0]
        self.psi.resize((self.dim_l,self.dim_r))
        maxiter = self.dim_l*self.dim_r
        (self.energy, self.psi) = lanczos(self, self.psi, maxiter, 1.e-7)


    def DensityMatrix(self, position):
        # Calculate density matrix
        if(position == Position.LEFT):
            self.rho = np.dot(self.psi,self.psi.transpose())
        else: 
            self.rho = np.dot(self.psi.transpose(),self.psi)

               
    def Truncate(self, position, m):
        # diagonalize rho
        rho_eig, rho_evec = np.linalg.eig(self.rho)
        self.nstates = m
        rho_evec = np.real(rho_evec)
        rho_eig = np.real(rho_eig)

        # calculate the truncation error for a given number of states m
        # Reorder eigenvectors and trucate
        index = np.argsort(rho_eig)
        for e in index:
            print "RHO EIGENVALUE ", rho_eig[e]
        error = 0.
        if (m < rho_eig.shape[0]):
            for i in range(index.shape[0]-m):
                error += rho_eig[index[i]]
        print "Truncation error = ", error

        aux = np.copy(rho_evec)
        if (self.rho.shape[0] > m):
            aux.resize((aux.shape[0],m))
            n = 0
            for i in range(index.shape[0]-1,index.shape[0]-1-m,-1):
                aux[:,n]=rho_evec[:,index[i]]
                n += 1
        rho_evec = aux       

#        rho_evec = np.eye(self.rho.shape[0])

        # perform transformation:
        U = rho_evec.transpose()
        if(position == Position.LEFT):
            aux2 = np.dot(self.HL[self.left_size],rho_evec)
            self.HL[self.left_size] = np.dot(U,aux2)
            aux2 = np.dot(self.splusL[self.left_size],rho_evec)
            self.splusL[self.left_size] = np.dot(U,aux2)
            aux2 = np.dot(self.szL[self.left_size],rho_evec)
            self.szL[self.left_size] = np.dot(U,aux2)
        else:
            aux2 = np.dot(self.HR[self.right_size],rho_evec)
            self.HR[self.right_size] = np.dot(U,aux2)
            aux2 = np.dot(self.splusR[self.right_size],rho_evec)
            self.splusR[self.right_size] = np.dot(U,aux2)
            aux2 = np.dot(self.szR[self.right_size],rho_evec)
            self.szR[self.right_size] = np.dot(U,aux2)
               
    def product(self, psi):
        npsi = np.dot(self.HL[self.left_size],psi)
        npsi += np.dot(psi,self.HR[self.right_size].transpose())
        # Sz.Sz
        tmat = np.dot(psi,self.szR[self.right_size].transpose())
        npsi += np.dot(self.szL[self.left_size],tmat)
        # S+.S-
        tmat = np.dot(psi,self.splusR[self.right_size])*0.5
        npsi += np.dot(self.splusL[self.left_size],tmat)
        # S-.S+
        tmat = np.dot(psi,self.splusR[self.right_size].transpose())*0.5
        npsi += np.dot(self.splusL[self.left_size].transpose(),tmat)

        return npsi

# %%
nsites = 8
n_states_to_keep = 10
n_sweeps = 4
S = DMRGSystem(nsites)
###############################################################################
for iter in range(1,nsites/2): # do infinite size dmrg for warmup
    print "WARMUP ITERATION ", iter, S.dim_l, S.dim_r
    # Create HL and HR by adding the single sites to the two blocks
    S.BuildBlockLeft(iter)
    S.BuildBlockRight(iter)
    # find smallest eigenvalue and eigenvector
    S.GroundState()
    # Calculate density matrix
    S.DensityMatrix(Position.LEFT)
    # Truncate
    S.Truncate(Position.LEFT,n_states_to_keep)
    # Reflect
    S.DensityMatrix(Position.RIGHT)
    S.Truncate(Position.RIGHT,n_states_to_keep)
    
first_iter = nsites/2
for sweep in range(1,n_sweeps):
    for iter in range(first_iter, nsites-3):
        print "LEFT-TO-RIGHT ITERATION ", iter, S.dim_l, S.dim_r
        # Create HL and HR by adding the single sites to the two blocks
        S.BuildBlockLeft(iter)
        S.BuildBlockRight(nsites-iter-2)
        # find smallest eigenvalue and eigenvector
        S.GroundState()
        # Calculate density matrix
        S.DensityMatrix(Position.LEFT)
        # Truncate
        S.Truncate(Position.LEFT,n_states_to_keep)
    first_iter = 1;
    for iter in range(first_iter, nsites-3):
        print "RIGHT-TO-LEFT ITERATION ", iter, S.dim_l, S.dim_r
        # Create HL and HR by adding the single sites to the two blocks
        S.BuildBlockRight(iter);
        S.BuildBlockLeft(nsites-iter-2)
        # find smallest eigenvalue and eigenvector
        S.GroundState();
        # Calculate density matrix
        S.DensityMatrix(Position.RIGHT)
        # Truncate
        S.Truncate(Position.RIGHT,n_states_to_keep)
# Out:
# WARMUP ITERATION  1 0 0
# Iter =  1  Ener =  0.242557842944
# Iter =  2  Ener =  -0.9097196433
# Iter =  3  Ener =  -1.56280455486
# Iter =  4  Ener =  -1.60266686303
# Iter =  5  Ener =  -1.61586872112
# Iter =  6  Ener =  -1.61602540378
# E0 =  -1.61602540378
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.933012701892
# Truncation error =  0.0
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.0223290993693
# RHO EIGENVALUE  0.933012701892
# Truncation error =  0.0
# WARMUP ITERATION  2 4 4
# Iter =  1  Ener =  -0.144769140807
# Iter =  2  Ener =  -1.33651924221
# Iter =  3  Ener =  -1.87172681299
# Iter =  4  Ener =  -2.02157918939
# Iter =  5  Ener =  -2.08549224295
# Iter =  6  Ener =  -2.20601842803
# Iter =  7  Ener =  -2.43363326083
# Iter =  8  Ener =  -2.47682684924
# Iter =  9  Ener =  -2.48603701974
# Iter =  10  Ener =  -2.48955366756
# Iter =  11  Ener =  -2.4905374403
# Iter =  12  Ener =  -2.49077766457
# Iter =  13  Ener =  -2.49081975882
# Iter =  14  Ener =  -2.49082529894
# Iter =  15  Ener =  -2.49082572882
# Iter =  16  Ener =  -2.49082587812
# Iter =  17  Ener =  -2.49082594101
# E0 =  -2.49082594101
# RHO EIGENVALUE  5.4453775859e-05
# RHO EIGENVALUE  7.02846848627e-05
# RHO EIGENVALUE  8.60299964766e-05
# RHO EIGENVALUE  0.000108576774452
# RHO EIGENVALUE  0.000775286572262
# RHO EIGENVALUE  0.00114082124291
# RHO EIGENVALUE  0.451602422369
# RHO EIGENVALUE  0.546162124584
# Truncation error =  0.0
# RHO EIGENVALUE  5.4453775859e-05
# RHO EIGENVALUE  7.02846848627e-05
# RHO EIGENVALUE  8.60299964766e-05
# RHO EIGENVALUE  0.000108576774452
# RHO EIGENVALUE  0.000775286572262
# RHO EIGENVALUE  0.00114082124291
# RHO EIGENVALUE  0.451602422369
# RHO EIGENVALUE  0.546162124584
# Truncation error =  0.0
# WARMUP ITERATION  3 8 8
# Iter =  1  Ener =  -0.0739618002148
# Iter =  2  Ener =  -1.38043598546
# Iter =  3  Ener =  -2.281643575
# Iter =  4  Ener =  -2.91873166423
# Iter =  5  Ener =  -3.21711710618
# Iter =  6  Ener =  -3.31564017347
# Iter =  7  Ener =  -3.3469703124
# Iter =  8  Ener =  -3.36054876488
# Iter =  9  Ener =  -3.36811742289
# Iter =  10  Ener =  -3.3711034836
# Iter =  11  Ener =  -3.37198755092
# Iter =  12  Ener =  -3.37218714948
# Iter =  13  Ener =  -3.37224419986
# Iter =  14  Ener =  -3.37226557145
# Iter =  15  Ener =  -3.37227428404
# Iter =  16  Ener =  -3.37227934422
# Iter =  17  Ener =  -3.37228128382
# Iter =  18  Ener =  -3.37228177535
# Iter =  19  Ener =  -3.37228188287
# Iter =  20  Ener =  -3.37228190799
# E0 =  -3.37228190799
# RHO EIGENVALUE  2.12468917142e-08
# RHO EIGENVALUE  2.43152016294e-08
# RHO EIGENVALUE  2.68593908732e-08
# RHO EIGENVALUE  2.86506164927e-08
# RHO EIGENVALUE  3.82105688408e-08
# RHO EIGENVALUE  1.42073409805e-07
# RHO EIGENVALUE  1.63982560665e-07
# RHO EIGENVALUE  2.0937517258e-07
# RHO EIGENVALUE  3.64851501242e-06
# RHO EIGENVALUE  1.14453104366e-05
# RHO EIGENVALUE  1.48366916013e-05
# RHO EIGENVALUE  1.861623535e-05
# RHO EIGENVALUE  0.0279463439659
# RHO EIGENVALUE  0.0343693813256
# RHO EIGENVALUE  0.0427565554822
# RHO EIGENVALUE  0.89487851776
# Truncation error =  2.81356079355e-07
# RHO EIGENVALUE  2.12468917142e-08
# RHO EIGENVALUE  2.43152016294e-08
# RHO EIGENVALUE  2.68593908732e-08
# RHO EIGENVALUE  2.86506164927e-08
# RHO EIGENVALUE  3.82105688406e-08
# RHO EIGENVALUE  1.42073409805e-07
# RHO EIGENVALUE  1.63982560665e-07
# RHO EIGENVALUE  2.09375172579e-07
# RHO EIGENVALUE  3.64851501242e-06
# RHO EIGENVALUE  1.14453104366e-05
# RHO EIGENVALUE  1.48366916013e-05
# RHO EIGENVALUE  1.861623535e-05
# RHO EIGENVALUE  0.0279463439659
# RHO EIGENVALUE  0.0343693813256
# RHO EIGENVALUE  0.0427565554822
# RHO EIGENVALUE  0.89487851776
# Truncation error =  2.81356079355e-07
# LEFT-TO-RIGHT ITERATION  4 16 16
# Iter =  1  Ener =  -0.540674614362
# Iter =  2  Ener =  -1.71598957796
# Iter =  3  Ener =  -2.56641029754
# Iter =  4  Ener =  -3.06002450891
# Iter =  5  Ener =  -3.19840929758
# Iter =  6  Ener =  -3.26322301126
# Iter =  7  Ener =  -3.32469240618
# Iter =  8  Ener =  -3.36080216814
# Iter =  9  Ener =  -3.36960960257
# Iter =  10  Ener =  -3.37152835878
# Iter =  11  Ener =  -3.37203651556
# Iter =  12  Ener =  -3.37218781913
# Iter =  13  Ener =  -3.37223945227
# Iter =  14  Ener =  -3.37226747697
# Iter =  15  Ener =  -3.37227788106
# Iter =  16  Ener =  -3.37228029935
# Iter =  17  Ener =  -3.3722806673
# Iter =  18  Ener =  -3.3722807449
# E0 =  -3.3722807449
# RHO EIGENVALUE  -2.08745457118e-19
# RHO EIGENVALUE  -1.75533719433e-22
# RHO EIGENVALUE  -5.91050879047e-23
# RHO EIGENVALUE  6.60778711791e-22
# RHO EIGENVALUE  6.60778711791e-22
# RHO EIGENVALUE  8.01657302452e-22
# RHO EIGENVALUE  3.64270285681e-21
# RHO EIGENVALUE  1.2972065245e-20
# RHO EIGENVALUE  7.40456055896e-20
# RHO EIGENVALUE  2.87755526602e-19
# RHO EIGENVALUE  5.92730390342e-19
# RHO EIGENVALUE  5.92730390342e-19
# RHO EIGENVALUE  0.000105045307145
# RHO EIGENVALUE  0.000125913452748
# RHO EIGENVALUE  0.00015168684439
# RHO EIGENVALUE  0.000186493375465
# RHO EIGENVALUE  0.00144075523841
# RHO EIGENVALUE  0.00174689540201
# RHO EIGENVALUE  0.458293418729
# RHO EIGENVALUE  0.537949791651
# Truncation error =  1.71559019094e-19
# RIGHT-TO-LEFT ITERATION  1 20 8
# Iter =  1  Ener =  -0.759855661503
# Iter =  2  Ener =  -2.25367756955
# Iter =  3  Ener =  -2.99723331801
# Iter =  4  Ener =  -3.27152838459
# Iter =  5  Ener =  -3.35028670133
# Iter =  6  Ener =  -3.36708179168
# Iter =  7  Ener =  -3.37128376056
# Iter =  8  Ener =  -3.37328753717
# Iter =  9  Ener =  -3.37389591693
# Iter =  10  Ener =  -3.37399296863
# Iter =  11  Ener =  -3.37400130052
# Iter =  12  Ener =  -3.37400311435
# Iter =  13  Ener =  -3.37400413569
# Iter =  14  Ener =  -3.37400439778
# Iter =  15  Ener =  -3.37400446906
# E0 =  -3.37400446906
# RHO EIGENVALUE  0.0247886148655
# RHO EIGENVALUE  0.0290375854352
# RHO EIGENVALUE  0.0345668873179
# RHO EIGENVALUE  0.911606912381
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  2 20 4
# Iter =  1  Ener =  -0.406009887335
# Iter =  2  Ener =  -1.60517108925
# Iter =  3  Ener =  -2.32446980551
# Iter =  4  Ener =  -2.74152635633
# Iter =  5  Ener =  -3.01332785735
# Iter =  6  Ener =  -3.20594826004
# Iter =  7  Ener =  -3.2878212123
# Iter =  8  Ener =  -3.33263532899
# Iter =  9  Ener =  -3.36100674036
# Iter =  10  Ener =  -3.37091418801
# Iter =  11  Ener =  -3.37312638496
# Iter =  12  Ener =  -3.37371249684
# Iter =  13  Ener =  -3.37387585632
# Iter =  14  Ener =  -3.37395521531
# Iter =  15  Ener =  -3.37399126098
# Iter =  16  Ener =  -3.37400218278
# Iter =  17  Ener =  -3.37400424629
# Iter =  18  Ener =  -3.37400457989
# Iter =  19  Ener =  -3.37400463331
# E0 =  -3.37400463331
# RHO EIGENVALUE  0.000102620962192
# RHO EIGENVALUE  0.000125479149057
# RHO EIGENVALUE  0.000156016350419
# RHO EIGENVALUE  0.000200056112821
# RHO EIGENVALUE  0.00142854464291
# RHO EIGENVALUE  0.0018473080299
# RHO EIGENVALUE  0.450343231793
# RHO EIGENVALUE  0.54579674296
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  3 20 8
# Iter =  1  Ener =  0.0386468215331
# Iter =  2  Ener =  -1.39651084452
# Iter =  3  Ener =  -2.29831770352
# Iter =  4  Ener =  -2.77401474751
# Iter =  5  Ener =  -2.97080598545
# Iter =  6  Ener =  -3.02316205835
# Iter =  7  Ener =  -3.05049681316
# Iter =  8  Ener =  -3.1034387843
# Iter =  9  Ener =  -3.25404806087
# Iter =  10  Ener =  -3.33658602114
# Iter =  11  Ener =  -3.36631061726
# Iter =  12  Ener =  -3.37281940368
# Iter =  13  Ener =  -3.37380592839
# Iter =  14  Ener =  -3.37396819293
# Iter =  15  Ener =  -3.37399513923
# Iter =  16  Ener =  -3.37400140269
# Iter =  17  Ener =  -3.37400376006
# Iter =  18  Ener =  -3.37400519311
# Iter =  19  Ener =  -3.37400566512
# Iter =  20  Ener =  -3.37400578549
# Iter =  21  Ener =  -3.37400581897
# E0 =  -3.37400581897
# RHO EIGENVALUE  1.94590894054e-08
# RHO EIGENVALUE  2.3289519789e-08
# RHO EIGENVALUE  2.55595988756e-08
# RHO EIGENVALUE  3.37610636125e-08
# RHO EIGENVALUE  3.84919569147e-08
# RHO EIGENVALUE  1.43462120963e-07
# RHO EIGENVALUE  1.67202692895e-07
# RHO EIGENVALUE  2.1129254259e-07
# RHO EIGENVALUE  3.75371993757e-06
# RHO EIGENVALUE  1.12402965003e-05
# RHO EIGENVALUE  1.51489741149e-05
# RHO EIGENVALUE  1.95813957322e-05
# RHO EIGENVALUE  0.0272270625391
# RHO EIGENVALUE  0.034219611081
# RHO EIGENVALUE  0.0442645775779
# RHO EIGENVALUE  0.894238361897
# Truncation error =  2.8402334956e-07
# RIGHT-TO-LEFT ITERATION  4 16 16
# Iter =  1  Ener =  -0.511531633817
# Iter =  2  Ener =  -1.69796588434
# Iter =  3  Ener =  -2.39730652143
# Iter =  4  Ener =  -2.86656211078
# Iter =  5  Ener =  -3.19790874657
# Iter =  6  Ener =  -3.3085408859
# Iter =  7  Ener =  -3.3394206408
# Iter =  8  Ener =  -3.35937377973
# Iter =  9  Ener =  -3.36978081475
# Iter =  10  Ener =  -3.37316611624
# Iter =  11  Ener =  -3.37376584214
# Iter =  12  Ener =  -3.37390486375
# Iter =  13  Ener =  -3.37396266471
# Iter =  14  Ener =  -3.37398960486
# Iter =  15  Ener =  -3.37400021966
# Iter =  16  Ener =  -3.3740037927
# Iter =  17  Ener =  -3.37400448399
# Iter =  18  Ener =  -3.37400464166
# Iter =  19  Ener =  -3.3740046766
# E0 =  -3.3740046766
# RHO EIGENVALUE  -6.75032548312e-19
# RHO EIGENVALUE  -8.96000730494e-20
# RHO EIGENVALUE  -1.65586607628e-21
# RHO EIGENVALUE  5.00291842702e-23
# RHO EIGENVALUE  5.00291842702e-23
# RHO EIGENVALUE  5.06998607964e-22
# RHO EIGENVALUE  1.364501554e-21
# RHO EIGENVALUE  1.364501554e-21
# RHO EIGENVALUE  1.13700402531e-20
# RHO EIGENVALUE  1.13700402531e-20
# RHO EIGENVALUE  2.21060659036e-19
# RHO EIGENVALUE  2.21060659036e-19
# RHO EIGENVALUE  8.88601785895e-05
# RHO EIGENVALUE  0.000115829235309
# RHO EIGENVALUE  0.000150968924134
# RHO EIGENVALUE  0.000200795585618
# RHO EIGENVALUE  0.00121301167826
# RHO EIGENVALUE  0.00195122351168
# RHO EIGENVALUE  0.435579303275
# RHO EIGENVALUE  0.560700007611
# Truncation error =  -7.40212346847e-19
# LEFT-TO-RIGHT ITERATION  1 8 20
# Iter =  1  Ener =  -1.03766257519
# Iter =  2  Ener =  -2.33429079512
# Iter =  3  Ener =  -2.88748747592
# Iter =  4  Ener =  -2.98804864178
# Iter =  5  Ener =  -3.05816200432
# Iter =  6  Ener =  -3.19151997732
# Iter =  7  Ener =  -3.3344251931
# Iter =  8  Ener =  -3.36861963524
# Iter =  9  Ener =  -3.37427643902
# Iter =  10  Ener =  -3.37486260971
# Iter =  11  Ener =  -3.37491493285
# Iter =  12  Ener =  -3.37492029701
# Iter =  13  Ener =  -3.37492138525
# Iter =  14  Ener =  -3.37492178942
# Iter =  15  Ener =  -3.37492198187
# Iter =  16  Ener =  -3.37492205027
# E0 =  -3.37492205027
# RHO EIGENVALUE  0.0295483341593
# RHO EIGENVALUE  0.0295807381266
# RHO EIGENVALUE  0.0296174936763
# RHO EIGENVALUE  0.911253434038
# Truncation error =  0.0
# LEFT-TO-RIGHT ITERATION  2 4 20
# Iter =  1  Ener =  -0.579220182672
# Iter =  2  Ener =  -1.88271581646
# Iter =  3  Ener =  -2.51945758859
# Iter =  4  Ener =  -2.8404455162
# Iter =  5  Ener =  -2.94684040045
# Iter =  6  Ener =  -2.98835474879
# Iter =  7  Ener =  -3.02383132791
# Iter =  8  Ener =  -3.11197107974
# Iter =  9  Ener =  -3.29659581902
# Iter =  10  Ener =  -3.36284203739
# Iter =  11  Ener =  -3.37324107865
# Iter =  12  Ener =  -3.374665302
# Iter =  13  Ener =  -3.37488973449
# Iter =  14  Ener =  -3.37492378371
# Iter =  15  Ener =  -3.3749292248
# Iter =  16  Ener =  -3.37493021922
# Iter =  17  Ener =  -3.3749303385
# Iter =  18  Ener =  -3.37493036262
# E0 =  -3.37493036262
# RHO EIGENVALUE  0.00014861610257
# RHO EIGENVALUE  0.000149013607852
# RHO EIGENVALUE  0.000149296297677
# RHO EIGENVALUE  0.000149312308314
# RHO EIGENVALUE  0.00166600746112
# RHO EIGENVALUE  0.00166692651799
# RHO EIGENVALUE  0.497898329077
# RHO EIGENVALUE  0.498172498627
# Truncation error =  0.0
# LEFT-TO-RIGHT ITERATION  3 8 20
# Iter =  1  Ener =  0.027047919754
# Iter =  2  Ener =  -1.27232487061
# Iter =  3  Ener =  -2.02984764435
# Iter =  4  Ener =  -2.71021682837
# Iter =  5  Ener =  -3.16288633034
# Iter =  6  Ener =  -3.27689557355
# Iter =  7  Ener =  -3.31923079902
# Iter =  8  Ener =  -3.35186994903
# Iter =  9  Ener =  -3.36916868246
# Iter =  10  Ener =  -3.37358249695
# Iter =  11  Ener =  -3.37462484936
# Iter =  12  Ener =  -3.37486822299
# Iter =  13  Ener =  -3.37492095
# Iter =  14  Ener =  -3.37493106281
# Iter =  15  Ener =  -3.37493239004
# Iter =  16  Ener =  -3.37493255986
# Iter =  17  Ener =  -3.3749325911
# E0 =  -3.3749325911
# RHO EIGENVALUE  2.77328984886e-08
# RHO EIGENVALUE  2.88544513053e-08
# RHO EIGENVALUE  2.92004983299e-08
# RHO EIGENVALUE  2.94549967216e-08
# RHO EIGENVALUE  3.07291619286e-08
# RHO EIGENVALUE  1.90657410379e-07
# RHO EIGENVALUE  1.91104427865e-07
# RHO EIGENVALUE  1.91989189005e-07
# RHO EIGENVALUE  4.1467447985e-06
# RHO EIGENVALUE  1.6449820033e-05
# RHO EIGENVALUE  1.65174714262e-05
# RHO EIGENVALUE  1.65606887735e-05
# RHO EIGENVALUE  0.0355246909075
# RHO EIGENVALUE  0.0355271259911
# RHO EIGENVALUE  0.0355302214812
# RHO EIGENVALUE  0.893363567172
# Truncation error =  3.36629417153e-07
# LEFT-TO-RIGHT ITERATION  4 16 16
# Iter =  1  Ener =  -0.469167349223
# Iter =  2  Ener =  -1.67335696309
# Iter =  3  Ener =  -2.49450778242
# Iter =  4  Ener =  -2.91794357907
# Iter =  5  Ener =  -3.11267129438
# Iter =  6  Ener =  -3.20139742398
# Iter =  7  Ener =  -3.29511026868
# Iter =  8  Ener =  -3.34992999359
# Iter =  9  Ener =  -3.36976861578
# Iter =  10  Ener =  -3.37420769563
# Iter =  11  Ener =  -3.37480636737
# Iter =  12  Ener =  -3.37491141781
# Iter =  13  Ener =  -3.37492741787
# Iter =  14  Ener =  -3.37493056203
# Iter =  15  Ener =  -3.37493113216
# Iter =  16  Ener =  -3.37493121804
# E0 =  -3.37493121804
# RHO EIGENVALUE  -4.31436860494e-18
# RHO EIGENVALUE  -4.31436860494e-18
# RHO EIGENVALUE  -1.96157917464e-18
# RHO EIGENVALUE  -1.31867848682e-18
# RHO EIGENVALUE  -1.31867848682e-18
# RHO EIGENVALUE  -5.39607049218e-20
# RHO EIGENVALUE  -1.44388447371e-20
# RHO EIGENVALUE  -5.95361610958e-21
# RHO EIGENVALUE  2.44282209449e-20
# RHO EIGENVALUE  7.06092715291e-20
# RHO EIGENVALUE  7.06092715291e-20
# RHO EIGENVALUE  1.36859800923e-18
# RHO EIGENVALUE  0.000148781783388
# RHO EIGENVALUE  0.000149024484628
# RHO EIGENVALUE  0.00014906344921
# RHO EIGENVALUE  0.000149345001091
# RHO EIGENVALUE  0.00166625023386
# RHO EIGENVALUE  0.00166698783713
# RHO EIGENVALUE  0.498015934467
# RHO EIGENVALUE  0.498054612744
# Truncation error =  -1.32069890315e-17
# RIGHT-TO-LEFT ITERATION  1 20 8
# Iter =  1  Ener =  -0.838255474205
# Iter =  2  Ener =  -1.82330106051
# Iter =  3  Ener =  -2.43232369748
# Iter =  4  Ener =  -2.89796060106
# Iter =  5  Ener =  -3.0773608643
# Iter =  6  Ener =  -3.19935006988
# Iter =  7  Ener =  -3.28699968973
# Iter =  8  Ener =  -3.34550414411
# Iter =  9  Ener =  -3.36937757348
# Iter =  10  Ener =  -3.37432027019
# Iter =  11  Ener =  -3.37486906497
# Iter =  12  Ener =  -3.37492428034
# Iter =  13  Ener =  -3.37493058321
# Iter =  14  Ener =  -3.3749311234
# Iter =  15  Ener =  -3.37493120847
# E0 =  -3.37493120847
# RHO EIGENVALUE  0.0295686767868
# RHO EIGENVALUE  0.0295791942237
# RHO EIGENVALUE  0.0295810835949
# RHO EIGENVALUE  0.911271045395
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  2 20 4
# Iter =  1  Ener =  -0.485638353309
# Iter =  2  Ener =  -1.59409548629
# Iter =  3  Ener =  -2.07238768126
# Iter =  4  Ener =  -2.51652731854
# Iter =  5  Ener =  -2.9342915498
# Iter =  6  Ener =  -3.0634831893
# Iter =  7  Ener =  -3.14429590397
# Iter =  8  Ener =  -3.26484823663
# Iter =  9  Ener =  -3.34618499276
# Iter =  10  Ener =  -3.369170848
# Iter =  11  Ener =  -3.37382262813
# Iter =  12  Ener =  -3.37477351339
# Iter =  13  Ener =  -3.37491378695
# Iter =  14  Ener =  -3.37492895147
# Iter =  15  Ener =  -3.37493073301
# Iter =  16  Ener =  -3.37493115053
# Iter =  17  Ener =  -3.37493121358
# E0 =  -3.37493121358
# RHO EIGENVALUE  0.000148801419607
# RHO EIGENVALUE  0.000148902101579
# RHO EIGENVALUE  0.000149132072775
# RHO EIGENVALUE  0.000149173454869
# RHO EIGENVALUE  0.00166581363932
# RHO EIGENVALUE  0.00166682432182
# RHO EIGENVALUE  0.498027538411
# RHO EIGENVALUE  0.498043814579
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  3 20 8
# Iter =  1  Ener =  -0.0376788298741
# Iter =  2  Ener =  -1.28454067865
# Iter =  3  Ener =  -2.21829720983
# Iter =  4  Ener =  -2.75232175627
# Iter =  5  Ener =  -2.99908547829
# Iter =  6  Ener =  -3.08342055342
# Iter =  7  Ener =  -3.1725589916
# Iter =  8  Ener =  -3.29140991682
# Iter =  9  Ener =  -3.34670311641
# Iter =  10  Ener =  -3.36863689815
# Iter =  11  Ener =  -3.37389753335
# Iter =  12  Ener =  -3.37477726817
# Iter =  13  Ener =  -3.3749066289
# Iter =  14  Ener =  -3.37492814763
# Iter =  15  Ener =  -3.37493193829
# Iter =  16  Ener =  -3.37493249593
# Iter =  17  Ener =  -3.3749325815
# E0 =  -3.3749325815
# RHO EIGENVALUE  2.64883941311e-08
# RHO EIGENVALUE  2.84860392256e-08
# RHO EIGENVALUE  3.05511147314e-08
# RHO EIGENVALUE  3.0941813169e-08
# RHO EIGENVALUE  3.14866832652e-08
# RHO EIGENVALUE  1.86974073547e-07
# RHO EIGENVALUE  1.87558826138e-07
# RHO EIGENVALUE  1.89968593781e-07
# RHO EIGENVALUE  4.14732645832e-06
# RHO EIGENVALUE  1.64059275567e-05
# RHO EIGENVALUE  1.64917493197e-05
# RHO EIGENVALUE  1.65286407276e-05
# RHO EIGENVALUE  0.0355209254354
# RHO EIGENVALUE  0.0355317431592
# RHO EIGENVALUE  0.0355351497753
# RHO EIGENVALUE  0.893357895531
# Truncation error =  3.34928118069e-07
# RIGHT-TO-LEFT ITERATION  4 16 16
# Iter =  1  Ener =  -0.281945912757
# Iter =  2  Ener =  -1.5833451155
# Iter =  3  Ener =  -2.60286932153
# Iter =  4  Ener =  -3.17673652903
# Iter =  5  Ener =  -3.33346796748
# Iter =  6  Ener =  -3.35958148093
# Iter =  7  Ener =  -3.36867960487
# Iter =  8  Ener =  -3.37260750321
# Iter =  9  Ener =  -3.37405579352
# Iter =  10  Ener =  -3.37476041255
# Iter =  11  Ener =  -3.3748971828
# Iter =  12  Ener =  -3.37492732236
# Iter =  13  Ener =  -3.37493082708
# Iter =  14  Ener =  -3.3749311913
# Iter =  15  Ener =  -3.37493122341
# E0 =  -3.37493122341
# RHO EIGENVALUE  -1.83326824154e-19
# RHO EIGENVALUE  -5.61162881501e-21
# RHO EIGENVALUE  -5.61162881501e-21
# RHO EIGENVALUE  -4.43441809921e-21
# RHO EIGENVALUE  -1.63613562701e-21
# RHO EIGENVALUE  -9.85150551448e-22
# RHO EIGENVALUE  1.24038452992e-21
# RHO EIGENVALUE  3.25146316482e-20
# RHO EIGENVALUE  1.15900818822e-19
# RHO EIGENVALUE  1.15900818822e-19
# RHO EIGENVALUE  2.0090291552e-19
# RHO EIGENVALUE  2.0090291552e-19
# RHO EIGENVALUE  0.000148741535967
# RHO EIGENVALUE  0.000148868710916
# RHO EIGENVALUE  0.000149024340301
# RHO EIGENVALUE  0.000149097079696
# RHO EIGENVALUE  0.00166530773953
# RHO EIGENVALUE  0.00166625442919
# RHO EIGENVALUE  0.498031816357
# RHO EIGENVALUE  0.498040889807
# Truncation error =  6.39508677595e-20
# LEFT-TO-RIGHT ITERATION  1 8 20
# Iter =  1  Ener =  -0.905687597293
# Iter =  2  Ener =  -1.85801830959
# Iter =  3  Ener =  -2.59139669878
# Iter =  4  Ener =  -2.92525138019
# Iter =  5  Ener =  -3.05444885199
# Iter =  6  Ener =  -3.14983994147
# Iter =  7  Ener =  -3.28776747675
# Iter =  8  Ener =  -3.35814461388
# Iter =  9  Ener =  -3.3724188819
# Iter =  10  Ener =  -3.37465576368
# Iter =  11  Ener =  -3.37490060626
# Iter =  12  Ener =  -3.37492608892
# Iter =  13  Ener =  -3.37493046796
# Iter =  14  Ener =  -3.37493103809
# Iter =  15  Ener =  -3.37493114177
# Iter =  16  Ener =  -3.37493120035
# E0 =  -3.37493120035
# RHO EIGENVALUE  0.0295656669794
# RHO EIGENVALUE  0.0295892136224
# RHO EIGENVALUE  0.0296033431187
# RHO EIGENVALUE  0.91124177628
# Truncation error =  0.0
# LEFT-TO-RIGHT ITERATION  2 4 20
# Iter =  1  Ener =  -0.252640488951
# Iter =  2  Ener =  -1.6791083296
# Iter =  3  Ener =  -2.5563483761
# Iter =  4  Ener =  -3.10507948114
# Iter =  5  Ener =  -3.29311573477
# Iter =  6  Ener =  -3.34103536907
# Iter =  7  Ener =  -3.35984363459
# Iter =  8  Ener =  -3.36951336198
# Iter =  9  Ener =  -3.37326127913
# Iter =  10  Ener =  -3.37457528053
# Iter =  11  Ener =  -3.3748783849
# Iter =  12  Ener =  -3.37492505808
# Iter =  13  Ener =  -3.3749306661
# Iter =  14  Ener =  -3.37493117152
# Iter =  15  Ener =  -3.37493121775
# E0 =  -3.37493121775
# RHO EIGENVALUE  0.000148972758941
# RHO EIGENVALUE  0.000149191870507
# RHO EIGENVALUE  0.000149310425099
# RHO EIGENVALUE  0.000149587481595
# RHO EIGENVALUE  0.00166789249108
# RHO EIGENVALUE  0.00166995423029
# RHO EIGENVALUE  0.498022273517
# RHO EIGENVALUE  0.498042817225
# Truncation error =  0.0
# LEFT-TO-RIGHT ITERATION  3 8 20
# Iter =  1  Ener =  0.114049700316
# Iter =  2  Ener =  -1.5169194701
# Iter =  3  Ener =  -2.52896124518
# Iter =  4  Ener =  -2.89603388991
# Iter =  5  Ener =  -3.05107349557
# Iter =  6  Ener =  -3.15475997416
# Iter =  7  Ener =  -3.25214337868
# Iter =  8  Ener =  -3.32426134603
# Iter =  9  Ener =  -3.35945075144
# Iter =  10  Ener =  -3.37188027231
# Iter =  11  Ener =  -3.37451689849
# Iter =  12  Ener =  -3.37487318948
# Iter =  13  Ener =  -3.37492277752
# Iter =  14  Ener =  -3.37493120982
# Iter =  15  Ener =  -3.37493242366
# Iter =  16  Ener =  -3.3749325662
# Iter =  17  Ener =  -3.37493259224
# E0 =  -3.37493259224
# RHO EIGENVALUE  2.95567642585e-08
# RHO EIGENVALUE  2.97490481538e-08
# RHO EIGENVALUE  3.02686927956e-08
# RHO EIGENVALUE  3.13046332556e-08
# RHO EIGENVALUE  3.16101090489e-08
# RHO EIGENVALUE  1.8803489134e-07
# RHO EIGENVALUE  1.89982682056e-07
# RHO EIGENVALUE  1.9029407822e-07
# RHO EIGENVALUE  4.1345022778e-06
# RHO EIGENVALUE  1.64282373386e-05
# RHO EIGENVALUE  1.64480066589e-05
# RHO EIGENVALUE  1.64874293281e-05
# RHO EIGENVALUE  0.035510747589
# RHO EIGENVALUE  0.0355116574812
# RHO EIGENVALUE  0.0355125169076
# RHO EIGENVALUE  0.893410859046
# Truncation error =  3.40524138852e-07
# LEFT-TO-RIGHT ITERATION  4 16 16
# Iter =  1  Ener =  -0.346541945495
# Iter =  2  Ener =  -1.5084898299
# Iter =  3  Ener =  -2.3298794308
# Iter =  4  Ener =  -2.80169419957
# Iter =  5  Ener =  -3.02210001972
# Iter =  6  Ener =  -3.11781464164
# Iter =  7  Ener =  -3.21335532571
# Iter =  8  Ener =  -3.31848181158
# Iter =  9  Ener =  -3.36344746252
# Iter =  10  Ener =  -3.37340111836
# Iter =  11  Ener =  -3.37470259546
# Iter =  12  Ener =  -3.37488796678
# Iter =  13  Ener =  -3.37492370323
# Iter =  14  Ener =  -3.37492983641
# Iter =  15  Ener =  -3.3749309732
# Iter =  16  Ener =  -3.3749311967
# Iter =  17  Ener =  -3.37493122481
# E0 =  -3.37493122481
# RHO EIGENVALUE  -5.88991701365e-18
# RHO EIGENVALUE  -5.88991701365e-18
# RHO EIGENVALUE  -3.13695638579e-19
# RHO EIGENVALUE  -3.13695638579e-19
# RHO EIGENVALUE  -6.02735031284e-21
# RHO EIGENVALUE  -6.02735031284e-21
# RHO EIGENVALUE  -5.01634439724e-21
# RHO EIGENVALUE  3.08994166606e-21
# RHO EIGENVALUE  3.08994166606e-21
# RHO EIGENVALUE  1.48669390216e-20
# RHO EIGENVALUE  1.71823613159e-19
# RHO EIGENVALUE  1.05928119665e-18
# RHO EIGENVALUE  0.000148914054238
# RHO EIGENVALUE  0.00014899034585
# RHO EIGENVALUE  0.00014915240517
# RHO EIGENVALUE  0.000149229975392
# RHO EIGENVALUE  0.00166659443154
# RHO EIGENVALUE  0.00166742458408
# RHO EIGENVALUE  0.498015781083
# RHO EIGENVALUE  0.498053913121
# Truncation error =  -1.24032495271e-17
# RIGHT-TO-LEFT ITERATION  1 20 8
# Iter =  1  Ener =  -0.903826642817
# Iter =  2  Ener =  -2.05061999302
# Iter =  3  Ener =  -2.81594674894
# Iter =  4  Ener =  -3.11360268402
# Iter =  5  Ener =  -3.20930509358
# Iter =  6  Ener =  -3.30234884557
# Iter =  7  Ener =  -3.36000342916
# Iter =  8  Ener =  -3.37244015054
# Iter =  9  Ener =  -3.37447088501
# Iter =  10  Ener =  -3.37488632312
# Iter =  11  Ener =  -3.37492623186
# Iter =  12  Ener =  -3.37493039364
# Iter =  13  Ener =  -3.37493099028
# Iter =  14  Ener =  -3.37493113007
# Iter =  15  Ener =  -3.37493119157
# E0 =  -3.37493119157
# RHO EIGENVALUE  0.0295832811422
# RHO EIGENVALUE  0.0295928672975
# RHO EIGENVALUE  0.0296030700369
# RHO EIGENVALUE  0.911220781523
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  2 20 4
# Iter =  1  Ener =  -0.224074928281
# Iter =  2  Ener =  -1.6380044458
# Iter =  3  Ener =  -2.52572971227
# Iter =  4  Ener =  -2.9470372606
# Iter =  5  Ener =  -3.1418751903
# Iter =  6  Ener =  -3.24325245567
# Iter =  7  Ener =  -3.3105857585
# Iter =  8  Ener =  -3.35382308095
# Iter =  9  Ener =  -3.37052846599
# Iter =  10  Ener =  -3.37427065871
# Iter =  11  Ener =  -3.37482611463
# Iter =  12  Ener =  -3.37491147267
# Iter =  13  Ener =  -3.3749281544
# Iter =  14  Ener =  -3.37493074417
# Iter =  15  Ener =  -3.37493115448
# Iter =  16  Ener =  -3.37493122124
# E0 =  -3.37493122124
# RHO EIGENVALUE  0.000148890818681
# RHO EIGENVALUE  0.000149105347558
# RHO EIGENVALUE  0.000149201007393
# RHO EIGENVALUE  0.000149437999728
# RHO EIGENVALUE  0.00166735506663
# RHO EIGENVALUE  0.00166801282136
# RHO EIGENVALUE  0.498024626897
# RHO EIGENVALUE  0.498043370041
# Truncation error =  0.0
# RIGHT-TO-LEFT ITERATION  3 20 8
# Iter =  1  Ener =  0.0261608079719
# Iter =  2  Ener =  -1.35988697267
# Iter =  3  Ener =  -2.32112453769
# Iter =  4  Ener =  -2.75676483426
# Iter =  5  Ener =  -2.91286422012
# Iter =  6  Ener =  -2.9685173971
# Iter =  7  Ener =  -2.99162315985
# Iter =  8  Ener =  -3.01138614072
# Iter =  9  Ener =  -3.12343993027
# Iter =  10  Ener =  -3.29790986543
# Iter =  11  Ener =  -3.3604285923
# Iter =  12  Ener =  -3.37230481533
# Iter =  13  Ener =  -3.37443709642
# Iter =  14  Ener =  -3.37485447193
# Iter =  15  Ener =  -3.37492007299
# Iter =  16  Ener =  -3.37493022063
# Iter =  17  Ener =  -3.37493222481
# Iter =  18  Ener =  -3.37493256341
# Iter =  19  Ener =  -3.37493259588
# E0 =  -3.37493259588
# RHO EIGENVALUE  2.96349048449e-08
# RHO EIGENVALUE  3.00434055692e-08
# RHO EIGENVALUE  3.0125281887e-08
# RHO EIGENVALUE  3.04327849685e-08
# RHO EIGENVALUE  3.0601465693e-08
# RHO EIGENVALUE  1.89072729632e-07
# RHO EIGENVALUE  1.89482945088e-07
# RHO EIGENVALUE  1.93387537542e-07
# RHO EIGENVALUE  4.14692338064e-06
# RHO EIGENVALUE  1.64492612349e-05
# RHO EIGENVALUE  1.64599682674e-05
# RHO EIGENVALUE  1.65188367674e-05
# RHO EIGENVALUE  0.0355162483576
# RHO EIGENVALUE  0.0355184263359
# RHO EIGENVALUE  0.0355192229442
# RHO EIGENVALUE  0.893391804592
# Truncation error =  3.39910572595e-07
# RIGHT-TO-LEFT ITERATION  4 16 16
# Iter =  1  Ener =  -0.403881619747
# Iter =  2  Ener =  -1.59879710573
# Iter =  3  Ener =  -2.45939716276
# Iter =  4  Ener =  -2.83315930367
# Iter =  5  Ener =  -2.95165288257
# Iter =  6  Ener =  -2.99696158224
# Iter =  7  Ener =  -3.03322127694
# Iter =  8  Ener =  -3.14840919306
# Iter =  9  Ener =  -3.32299440984
# Iter =  10  Ener =  -3.36780381943
# Iter =  11  Ener =  -3.37375652468
# Iter =  12  Ener =  -3.37471194352
# Iter =  13  Ener =  -3.37489386906
# Iter =  14  Ener =  -3.3749250652
# Iter =  15  Ener =  -3.37493029336
# Iter =  16  Ener =  -3.37493111237
# Iter =  17  Ener =  -3.37493121656
# Iter =  18  Ener =  -3.37493122679
# E0 =  -3.37493122679
# RHO EIGENVALUE  -8.82162781207e-19
# RHO EIGENVALUE  -8.82162781207e-19
# RHO EIGENVALUE  -8.22659482551e-20
# RHO EIGENVALUE  -8.22659482551e-20
# RHO EIGENVALUE  -3.52096345833e-20
# RHO EIGENVALUE  -3.52096345833e-20
# RHO EIGENVALUE  -4.08336873126e-22
# RHO EIGENVALUE  -4.08336873126e-22
# RHO EIGENVALUE  5.53682456249e-21
# RHO EIGENVALUE  1.271518728e-20
# RHO EIGENVALUE  4.8985466563e-19
# RHO EIGENVALUE  4.8985466563e-19
# RHO EIGENVALUE  0.000148918592523
# RHO EIGENVALUE  0.000148985705019
# RHO EIGENVALUE  0.000149174144776
# RHO EIGENVALUE  0.00014921603604
# RHO EIGENVALUE  0.00166691017428
# RHO EIGENVALUE  0.00166701856745
# RHO EIGENVALUE  0.49802787954
# RHO EIGENVALUE  0.49804189724
# Truncation error =  -1.98184139e-18
